# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.linear_model
import sklearn.model_selection
import sklearn.preprocessing
import scipy.integrate
import sklearn.discriminant_analysis
import sklearn.ensemble
import sklearn.tree
import itertools
import sklearn.tree
import sklearn.metrics
import scipy
from pandas.tools.plotting import scatter_matrix
from sklearn.svm import LinearSVC
from sklearn.datasets import make_classification
from sklearn import svm

# %matplotlib inline

# %%
data=pd.read_csv('OJ.csv')
data= data.dropna()
WeekofPurchase=data['WeekofPurchase']
StoreID=data['StoreID']
PriceCH=data['PriceCH'] 
PriceMM=data['PriceMM']
DiscCH=data['DiscCH']
DiscMM=data['DiscMM']
SpecialCH=data['SpecialCH']
SpecialMM=data['SpecialMM'] 
LoyalCH=data['LoyalCH']
SalePriceMM=data['SalePriceMM']
SalePriceCH=data['SalePriceCH']
PriceDiff=data['PriceDiff']
PctDiscMM=data['PctDiscMM']
PctDiscCH=data['PctDiscCH']
ListPriceDiff=data['ListPriceDiff']
STORE=data['STORE']
Purchase=list(data['Purchase'])
purchase=[]
for i in range(len(Purchase)):
    if Purchase[i]=='CH':
        purchase.append(1)
    if Purchase[i]=='MM':
        purchase.append(0)
x=(np.array([LoyalCH,PriceDiff])).T
y=np.array(purchase)
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y, test_size=0.25, random_state=1)

# %% [markdown]
# (Primera parte)
#
# a) Sin utilizar funciones de sklearn, utilice el data set OJ para encontrar la recta en el espacio de parametros LoyalCH-PriceDiff que mejor logra dividir Purchase en dos clases.

# %%
def svm_sgd(X, Y):
    w = np.zeros(len(X[0]))
    eta = 1
    n = 1000
    for n in range(1,n):
        for i, x in enumerate(X):
            if (Y[i]*np.dot(X[i], w)) < 1:
                w = w + eta * ( (X[i] * Y[i]) + (-2* w/n) )
            else:
                w = w + eta * (-2*w/n)
    return w

# %%
w=svm_sgd(x_train,y_train)

# %%
w
# Out:
# array([3.21690627, 0.86089201])

# %%
x2=[w[0],w[1],-w[1],w[0]]
x3=[w[0],w[1],w[1],-w[0]]
x2x3 =np.array([x2,x3])
X,Y,U,V = zip(*x2x3)
ax = plt.gca()
ax.quiver(X,Y,U,V,scale=1, color='blue')
plt.scatter(x_train[:,0],x_train[:,1], c=y_train)

# %%
plt.scatter(x_train[:,0],x_train[:,1], c=y_train)
plt.xlabel('LoyalCH')
plt.ylabel('PriceDiff')
a = -w[0] / w[1]

x = np.linspace(0,1)
y = a * x 

line = plt.plot(x, y)

# %% [markdown]
# ## b.

# %%
clf = svm.SVC(kernel='linear', C=1000)
clf.fit(x_train, y_train)
# Out:
# SVC(C=1000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
w = clf.coef_[0]
a = -w[0] / w[1]
xx = np.linspace(0,1)
yy = a * xx - (clf.intercept_[0]) / w[1]
plt.plot(xx, yy, 'k-')
plt.scatter(x_train[:,0],x_train[:,1], c=y_train)

# %%
clf.intercept_
# Out:
# array([-2.31769754])

# %% [markdown]
# ## c.

# %%
clf = svm.SVC(kernel='linear', C=1000)
clf.fit(x_train, y_train)
# Out:
# SVC(C=1000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
plt.scatter(x_train[:, 0], x_train[:, 1], c=y_train, s=30, cmap=plt.cm.Paired)

# plot the decision function
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

# create grid to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = clf.decision_function(xy).reshape(XX.shape)

# plot decision boundary and margins
ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5,
           linestyles=['--', '-', '--'])
plt.show()

# %% [markdown]
# # Segunda Parte

# %%
data=pd.read_csv('Cars93.csv')
data= data.dropna()

# %%
Fueltankcapacity=data['Fuel.tank.capacity']
Horsepower=data['Horsepower'] 
Length=data['Length']
Revpermile=data['Rev.per.mile']
Turncircle=data['Turn.circle']
Weight=data['Weight']
MPGcity=data['MPG.city']

# %%
x=(np.array([Fueltankcapacity,Horsepower,Length,Revpermile,Turncircle,Weight])).T
y_=list(data['MPG.city'])
meany=np.mean(y_)
y=[]
for i in range(len(y_)):
    if y_[i]>meany:
        y.append(1)
    if y_[i]<=meany:
        y.append(-1)

# %%
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y, test_size=0.25, random_state=1)

# %%
k=1
for i in range(len(x_train[:,0])):
    for j in range(i+1,len(x_train[0,:])):
        #plt.figure(figsize=[6.4, 4.8])
        plt.subplot(5,3,k)
        plt.scatter(x_train[:,i],x_train[:,j],c=y_train)
        k +=1

# %%
k=1
for i in range(len(x_train[:,0])):
    for j in range(i+1,len(x_train[0,:])):
        plt.subplot(3,5,k)
        plt.scatter(x_train[:,i],x_train[:,j],c=y_train)
        clf = svm.SVC(kernel='linear', C=1)
        clf.fit(x_train[:,i],y_train)
        w = clf.coef_[0]
        a = -w[i] / w[j]
        xx = np.linspace(-5, 5)
        yy = a * xx - (clf.intercept_[i]) / w[j]
        plt.plot(xx, yy, 'k-')
        k +=1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-219-0aff8f7cacfb> in <module>()
#       5         plt.scatter(x_train[:,i],x_train[:,j],c=y_train)
#       6         clf = svm.SVC(kernel='linear', C=1)
# ----> 7         clf.fit(x_train[:,i],y_train)
#       8         w = clf.coef_[0]
#       9         a = -w[i] / w[j]
#
# ~\Anaconda3\lib\site-packages\sklearn\svm\base.py in fit(self, X, y, sample_weight)
#     147         self._sparse = sparse and not callable(self.kernel)
#     148
# --> 149         X, y = check_X_y(X, y, dtype=np.float64, order='C', accept_sparse='csr')
#     150         y = self._validate_targets(y)
#     151
#
# ...

# %%
clf.coef_
# Out:
# array([-714.78085979,   30.12819011,    5.86122969,    2.12154995,
#         379.87838647,   -2.67188159])

# %%
w = clf.coef_[0]
a = -w[0] / w[5]
xx = np.linspace(0,25)
yy = a * xx - (clf.intercept_[0]) / w[1]
plt.plot(xx, yy, 'k-')
plt.scatter(x_train[:,0],x_train[:,1], c=y_train)

# %%
plt.scatter(x_train[:, 0], x_train[:, 1], c=y_train, s=30, cmap=plt.cm.Paired)
plt.xlabel('Fueltankcapacity')
plt.ylabel('Horsepower')
# Out:
# Text(0,0.5,'Horsepower')

# %%
plt.scatter(x_train[:, 0], x_train[:, 2], c=y_train, s=30, cmap=plt.cm.Paired)
plt.xlabel('Fueltankcapacity')
plt.ylabel('Length')
# Out:
# Text(0,0.5,'Length')

# %%
plt.scatter(x_train[:, 0], x_train[:, 3], c=y_train, s=30, cmap=plt.cm.Paired)
plt.xlabel('Fueltankcapacity')
plt.ylabel('Revpermile')
# Out:
# Text(0,0.5,'Revpermile')

# %%
plt.scatter(x_train[:, 0], x_train[:, 4], c=y_train, s=30, cmap=plt.cm.Paired)
plt.xlabel('Fueltankcapacity')
plt.ylabel('Turncircle')
# Out:
# Text(0,0.5,'Turncircle')

# %%
plt.scatter(x_train[:, 0], x_train[:, 5], c=y_train, s=30, cmap=plt.cm.Paired)
plt.xlabel('Fueltankcapacity')
plt.ylabel('Weight')
# Out:
# Text(0,0.5,'Weight')

# %%
plt.scatter(x_train[:, 1], x_train[:, 2], c=y_train, s=30, cmap=plt.cm.Paired)
plt.xlabel('Horsepower')
plt.ylabel('Length')

# %%
plt.scatter(x_train[:, 1], x_train[:, 3], c=y_train, s=30, cmap=plt.cm.Paired)
plt.xlabel('Horsepower')
plt.ylabel('Revpermile')

# %%
plt.scatter(x_train[:, 1], x_train[:, 4], c=y_train, s=30, cmap=plt.cm.Paired)
plt.xlabel('Horsepower')
plt.ylabel('Turncircle')

# %%
plt.scatter(x_train[:, 1], x_train[:, 5], c=y_train, s=30, cmap=plt.cm.Paired)
plt.xlabel('Horsepower')
plt.ylabel('Weight')
